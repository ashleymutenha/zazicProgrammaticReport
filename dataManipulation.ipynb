# %%
import pandas as pd
import json

dashboard = pd.ExcelFile("data.xlsx")

# %%
data = pd.read_excel(dashboard,"Statistics")

aes = pd.read_excel(dashboard,"AEs")

referrals = pd.read_excel(dashboard, "Referrals")

partnerDistricts = pd.read_excel("partnerDistrict.xlsx")

# %%
data['totalMCs'] = data['mc15-19'] + data['mc20-24'] +data['mc25-29']+data['mc30-34']+data['mc35-39'] + data['mc40-44'] + data['mc45-49']+ data['mc50']

data
# Out:
#    AERecordingMonth  AERecordingSite  AERecordingYear   District  \
# 0                 0                0                0  MBERENGWA
# 1                 0                0                0  MBERENGWA
# 2                 0                0                0  MBERENGWA
# 3                 0                0                0  MBERENGWA
# 4                 0                0                0  MBERENGWA
# 5                 0                0                0  MBERENGWA
# 6                 0                0                0  MBERENGWA
# 7                 0                0                0  MBERENGWA
#
#    ReferrelRecordingMonth  ReferrelRecordingSite  ReferrelRecordingYear  \
# 0                       0                      0                      0
# 1                       0                      0                      0
# 2                       0                      0                      0
# 3                       0                      0                      0
# 4                       0                      0                      0
# 5                       0                      0                      0
# 6                       0                      0                      0
# 7                       0                      0                      0
#
#                            Site_Name  TotalMCsBYMethod  aeComments  ...  \
# 0  MNENE - 101029 - MISSION HOSPITAL                24           0  ...
# 1  MNENE - 101029 - MISSION HOSPITAL                20           0  ...
# 2  MNENE - 101029 - MISSION HOSPITAL                33           0  ...
# 3  MNENE - 101029 - MISSION HOSPITAL                 2           0  ...
# 4  MNENE - 101029 - MISSION HOSPITAL                14           0  ...
# 5  MNENE - 101029 - MISSION HOSPITAL                 6           0  ...
# 6  MNENE - 101029 - MISSION HOSPITAL                12           0  ...
# 7  MNENE - 101029 - MISSION HOSPITAL                18           0  ...
#
#    total_mcs_referred_for_sti_services  total_mcs_referred_to_other_services  \
# 0                                    0                                     0
# 1                                    0                                     0
# 2                                    1                                     0
# 3                                    0                                     0
# 4                                    0                                     0
# 5                                    0                                     0
# 6                                    2                                     0
# 7                                    0                                     0
#
#    total_surgicalDisposable  total_surgicalReusable  totalhivNegative  \
# 0                        OK                       0                24
# 1                        OK                       0                 0
# 2                        OK                       0                33
# 3                        OK                       0                 2
# 4                        OK                       0                14
# 5                        OK                       0                 6
# 6                        OK                       0                12
# 7                        OK                      OK                 0
#
#    totalhivNegativeNC  uncircumcisedClientsForHTS  vmmc_number  year  \
# 0                   0                         1.0            0  2025
# 1                   0                         NaN            0  2026
# 2                   0                         1.0            0  2025
# 3                   0                         0.0            0  2025
# 4                   0                         0.0            0  2025
# 5                   0                         0.0            0  2025
# 6                   3                         1.0            0  2025
# 7                   0                         0.0            0  2025
#
#   facilityType
# 0     Outreach
# 1       Static
# 2     Outreach
# 3     Outreach
# 4     Outreach
# 5     Outreach
# 6       Static
# 7     Outreach
#
# [8 rows x 139 columns]

# %%
aes
# Out:
#    AERecordingMonth  AERecordingSite  AERecordingYear   District  aeComments  \
# 0                 0                0                0  MBERENGWA           0
#
#    ae_classification  ae_type_code  circumcising_cadre  client_age  \
# 0                  0             0                   0           0
#
#    date_ae_identified  mcMethod  vmmc_number
# 0                   0         0            0

# %%
# Ensure Month-Year columns are strings for easy comparison
data['year'] = data['year'].astype(str)
aes['AERecordingYear'] = aes['AERecordingYear'].astype(str)

data['recordingMonth'] = data['recordingMonth'].astype(str)
aes['AERecordingMonth'] = aes['AERecordingMonth'].astype(str)

# Transform df1 to include the list object
json_data = []

for _, row in data.iterrows():
    row_data = row.to_dict()
    print(type(row['totalAES']))
    if row['totalAES'] >= 1:
        # Filter df2 to find matching rows
        recordedAEs = aes[
            (aes['AERecordingSite'] == row['facilityName']) &
            (aes['AERecordingMonth'] == row['recordingMonth']) &
            (aes['AERecordingYear'] == row['year'])
        ]

        print(recordedAEs)
        
        # Add list object to the row if matches are found
        row_data['matchingAES'] = recordedAEs.to_dict(orient='records')
    else:
        # Add an empty list if no matches
        row_data['matchingAES'] = []


    if row['referralToOtherServices'] >= 1:
        # Filter df2 to find matching rows
        otherReferrals = referrals[
            (referrals['ReferrelRecordingSite'] == row['facilityName']) &
            (referrals['ReferrelRecordingMonth'] == row['recordingMonth']) &
            (referrals['ReferrelRecordingYear'] == row['year'])
        ]


        # Add list object to the row if matches are found
        row_data['otherReferrals'] = otherReferrals.to_dict(orient='records')
    else:
        # Add an empty list if no matches
        row_data['otherReferrals'] = []
    
    # Append to the final JSON structure
    json_data.append(row_data)

# Convert to JSON
result_json = json.dumps(json_data, indent=4)

output_file = "data.json"

# Save the JSON data to the file
with open(output_file, "w") as file:
    json.dump(json_data, file, indent=4)

# Print the JSON
print(result_json)
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# [
#     {
#         "AERecordingMonth": 0,
#         "AERecordingSite": 0,
#         "AERecordingYear": 0,
#         "District": "MBERENGWA",
#         "ReferrelRecordingMonth": 0,
#         "ReferrelRecordingSite": 0,
#         "ReferrelRecordingYear": 0,
#         "Site_Name": "MNENE - 101029 - MISSION HOSPITAL",
#         "TotalMCsBYMethod": 24,
#         "aeComments": 0,
#         "ae_classification": 0,
#         "ae_type_code": 0,
#         "ageGroupsChange": 0,
#         "checkMonthValidation": 0,
#         "checkYearValidation": 0,
#         "checkifFacilityHasBeenSaved": 0,
#         "circumcising_cadre": 0,
#         "client_age": 0,
#         "date_ae_identified": 0,
#         "facilityName": "Chiedza Clinic",
#         "followUpTotal": NaN,
#         "formType": "submission",
#         "fu15-19": 9,
#         "fu20-24": 8,
#         "fu25-29": 0,
#         "fu30-34": 1,
#         "fu35-39": 0,
#         "fu40-44": 0,
#         "fu45-49": 0,
#         "fu50": 0,
#         "high_risk_referrals_to_care": 0,
#         "hivNegative15-19": 12,
#         "hivNegative20-24": 10,
#         "hivNegative25-29": 0,
#         "hivNegative30-34": 2,
#         "hivNegative35-39": 0,
#         "hivNegative40-44": 0,
#         "hivNegative45-49": 0,
#         "hivNegative50": 0,
#         "hivNegativeNC15-19": 0,
#         "hivNegativeNC20-24": 0,
#         "hivNegativeNC25-29": 0,
#         "hivNegativeNC30-34": 0,
#         "hivNegativeNC35-39": 0,
#         "hivNegativeNC40-44": 0,
#         "hivNegativeNC45-49": 0,
#         "hivNegativeNC50": 0,
#         "hivPositive15-19": 0,
#         "hivPositive20-24": 0,
#         "hivPositive25-29": 0,
#         "hivPositive30-34": 0,
#         "hivPositive35-39": 0,
#         "hivPositive40-44": 0,
#         "hivPositive45-49": 0,
#         "hivPositive50": 0,
#         "hivPositiveNC15-19": 1,
#         "hivPositiveNC20-24": 2,
#         "hivPositiveNC25-29": 0,
#         "hivPositiveNC35-39": 0,
#         "hivPositiveNC40-44": 0,
#         "hivPositiveNC45-49": 0,
#         "hivPositiveNC50": 0,
#         "mc15-19": 12,
#         "mc20-24": 10,
#         "mc25-29": 0,
#         "mc30-34": 2,
#         "mc35-39": 0,
#         "mc40-44": 0,
#         "mc45-49": 0,
#         "mc50": NaN,
#         "mcMethod": 0,
#         "reason_for_referral": 0,
#         "received_on": "2025-04-22T05:55:52.253417Z",
#         "recordingMonth": "March",
#         "referralToOtherServices": 0,
#         "services_referred": 0,
#         "sgDisposable15-19": 12,
#         "sgDisposable20-24": 10,
#         "sgDisposable25-29": 0,
#         "sgDisposable30-34": 2,
#         "sgDisposable35-39": 0,
#         "sgDisposable40-44": 0,
#         "sgDisposable45-49": 0,
#         "sgDisposable50": 0,
#         "sgReusable15-19": 0,
#         "sgReusable20-24": 0,
#         "sgReusable25-29": 0,
#         "sgReusable30-34": 0,
#         "sgReusable35-39": 0,
#         "sgReusable40-44": 0,
#         "sgReusable45-49": 0,
#         "sgReusable50": 0,
#         "shangring15-19": 0,
#         "shangring20-24": 0,
#         "shangring25-29": 0,
#         "shangring30-34": 0,
#         "shangring35-39": 0,
#         "shangring40-44": 0,
#         "shangring45-49": 0,
#         "shangring50": 0,
#         "total15-19HIVTested": NaN,
#         "total15-19NCHIVTested": 1,
#         "total20-24HIVTested": NaN,
#         "total20-24NCHIVTested": 2,
#         "total25-29HIVTested": NaN,
#         "total25-29NCHIVTested": 0,
#         "total30-34HIVTested": NaN,
#         "total30-34NCHIVTested": 0,
#         "total35-39HIVTested": NaN,
#         "total35-39NCHIVTested": 0,
#         "total40-44HIVTested": NaN,
#         "total40-44NCHIVTested": 0,
#         "total45-49HIVTested": NaN,
#         "total45-49NCHIVTested": 0,
#         "total50ByMethod": NaN,
#         "total50HIVTested": NaN,
#         "total50NCHIVTested": 0,
#         "totalAES": 0,
#         "totalHIVPositive": 0,
#         "totalHIVPositiveNC": 3,
#         "totalHIVUntested": 0,
#         "totalMCs": NaN,
#         "totalReferralstoOtherServices": 0,
#         "totalShangringMCs": 0,
#         "totalSurgicalDisposableMCs": 24,
#         "totalSurgicalReusableMCs": 0,
#         "total_hiv_negative_linked_to_prep": 0,
#         "total_hiv_positive_linked_to_care": 3,
#         "total_mcs_referred_for_srh_services": 0,
#         "total_mcs_referred_for_sti_services": 0,
#         "total_mcs_referred_to_other_services": 0,
#         "total_surgicalDisposable": "OK",
#         "total_surgicalReusable": 0,
#         "totalhivNegative": 24,
#         "totalhivNegativeNC": 0,
#         "uncircumcisedClientsForHTS": 1.0,
#         "vmmc_number": 0,
#         "year": "2025",
#         "facilityType": "Outreach",
#         "matchingAES": [],
#         "otherReferrals": []
#     },
#     {
#         "AERecordingMonth": 0,
#         "AERecordingSite": 0,
#         "AERecordingYear": 0,
#         "District": "MBERENGWA",
#         "ReferrelRecordingMonth": 0,
#         "ReferrelRecordingSite": 0,
#         "ReferrelRecordingYear": 0,
#         "Site_Name": "MNENE - 101029 - MISSION HOSPITAL",
#         "TotalMCsBYMethod": 20,
#         "aeComments": 0,
#         "ae_classification": 0,
#         "ae_type_code": 0,
#         "ageGroupsChange": 0,
#         "checkMonthValidation": 0,
#         "checkYearValidation": 0,
#         "checkifFacilityHasBeenSaved": 0,
#         "circumcising_cadre": 0,
#         "client_age": 0,
#         "date_ae_identified": 0,
#         "facilityName": "Mnene Hospital",
#         "followUpTotal": NaN,
#         "formType": "submission",
#         "fu15-19": 0,
#         "fu20-24": 20,
#         "fu25-29": 0,
#         "fu30-34": 0,
#         "fu35-39": 0,
#         "fu40-44": 0,
#         "fu45-49": 0,
#         "fu50": 0,
#         "high_risk_referrals_to_care": 0,
#         "hivNegative15-19": 0,
#         "hivNegative20-24": 0,
#         "hivNegative25-29": 0,
#         "hivNegative30-34": 0,
#         "hivNegative35-39": 0,
#         "hivNegative40-44": 0,
#         "hivNegative45-49": 0,
#         "hivNegative50": 0,
#         "hivNegativeNC15-19": 0,
#         "hivNegativeNC20-24": 0,
#         "hivNegativeNC25-29": 0,
#         "hivNegativeNC30-34": 0,
#         "hivNegativeNC35-39": 0,
#         "hivNegativeNC40-44": 0,
#         "hivNegativeNC45-49": 0,
#         "hivNegativeNC50": 0,
#         "hivPositive15-19": 0,
#         "hivPositive20-24": 0,
#         "hivPositive25-29": 0,
#         "hivPositive30-34": 0,
#         "hivPositive35-39": 0,
#         "hivPositive40-44": 0,
#         "hivPositive45-49": 0,
#         "hivPositive50": 0,
#         "hivPositiveNC15-19": 0,
#         "hivPositiveNC20-24": 0,
#         "hivPositiveNC25-29": 0,
#         "hivPositiveNC35-39": 0,
#         "hivPositiveNC40-44": 0,
#         "hivPositiveNC45-49": 0,
#         "hivPositiveNC50": 0,
#         "mc15-19": 0,
#         "mc20-24": 20,
#         "mc25-29": 0,
#         "mc30-34": 0,
#         "mc35-39": 0,
#         "mc40-44": 0,
#         "mc45-49": 0,
#         "mc50": NaN,
#         "mcMethod": 0,
#         "reason_for_referral": 0,
#         "received_on": "2025-04-03T22:40:10.996208Z",
#         "recordingMonth": "March",
#         "referralToOtherServices": 0,
#         "services_referred": 0,
#         "sgDisposable15-19": 0,
#         "sgDisposable20-24": 20,
#         "sgDisposable25-29": 0,
#         "sgDisposable30-34": 0,
#         "sgDisposable35-39": 0,
#         "sgDisposable40-44": 0,
#         "sgDisposable45-49": 0,
#         "sgDisposable50": 0,
#         "sgReusable15-19": 0,
#         "sgReusable20-24": 0,
#         "sgReusable25-29": 0,
#         "sgReusable30-34": 0,
#         "sgReusable35-39": 0,
#         "sgReusable40-44": 0,
#         "sgReusable45-49": 0,
#         "sgReusable50": 0,
#         "shangring15-19": 0,
#         "shangring20-24": 0,
#         "shangring25-29": 0,
#         "shangring30-34": 0,
#         "shangring35-39": 0,
#         "shangring40-44": 0,
#         "shangring45-49": 0,
#         "shangring50": 0,
#         "total15-19HIVTested": NaN,
#         "total15-19NCHIVTested": 0,
#         "total20-24HIVTested": 0.0,
#         "total20-24NCHIVTested": 0,
#         "total25-29HIVTested": NaN,
#         "total25-29NCHIVTested": 0,
#         "total30-34HIVTested": NaN,
#         "total30-34NCHIVTested": 0,
#         "total35-39HIVTested": NaN,
#         "total35-39NCHIVTested": 0,
#         "total40-44HIVTested": NaN,
#         "total40-44NCHIVTested": 0,
#         "total45-49HIVTested": NaN,
#         "total45-49NCHIVTested": 0,
#         "total50ByMethod": NaN,
#         "total50HIVTested": NaN,
#         "total50NCHIVTested": 0,
#         "totalAES": 0,
#         "totalHIVPositive": 0,
#         "totalHIVPositiveNC": 0,
#         "totalHIVUntested": 20,
#         "totalMCs": NaN,
#         "totalReferralstoOtherServices": 0,
#         "totalShangringMCs": 0,
#         "totalSurgicalDisposableMCs": 20,
#         "totalSurgicalReusableMCs": 0,
#         "total_hiv_negative_linked_to_prep": 0,
#         "total_hiv_positive_linked_to_care": 0,
#         "total_mcs_referred_for_srh_services": 0,
#         "total_mcs_referred_for_sti_services": 0,
#         "total_mcs_referred_to_other_services": 0,
#         "total_surgicalDisposable": "OK",
#         "total_surgicalReusable": 0,
#         "totalhivNegative": 0,
#         "totalhivNegativeNC": 0,
#         "uncircumcisedClientsForHTS": NaN,
#         "vmmc_number": 0,
#         "year": "2026",
#         "facilityType": "Static",
#         "matchingAES": [],
#         "otherReferrals": []
#     },
#     {
#         "AERecordingMonth": 0,
#         "AERecordingSite": 0,
#         "AERecordingYear": 0,
#         "District": "MBERENGWA",
#         "ReferrelRecordingMonth": 0,
#         "ReferrelRecordingSite": 0,
#         "ReferrelRecordingYear": 0,
#         "Site_Name": "MNENE - 101029 - MISSION HOSPITAL",
#         "TotalMCsBYMethod": 33,
#         "aeComments": 0,
#         "ae_classification": 0,
#         "ae_type_code": 0,
#         "ageGroupsChange": 0,
#         "checkMonthValidation": 0,
#         "checkYearValidation": 0,
#         "checkifFacilityHasBeenSaved": 0,
#         "circumcising_cadre": 0,
#         "client_age": 0,
#         "date_ae_identified": 0,
#         "facilityName": "Gaha Clinic",
#         "followUpTotal": NaN,
#         "formType": "submission",
#         "fu15-19": 21,
#         "fu20-24": 12,
#         "fu25-29": 0,
#         "fu30-34": 0,
#         "fu35-39": 0,
#         "fu40-44": 0,
#         "fu45-49": 0,
#         "fu50": 0,
#         "high_risk_referrals_to_care": 1,
#         "hivNegative15-19": 21,
#         "hivNegative20-24": 12,
#         "hivNegative25-29": 0,
#         "hivNegative30-34": 0,
#         "hivNegative35-39": 0,
#         "hivNegative40-44": 0,
#         "hivNegative45-49": 0,
#         "hivNegative50": 0,
#         "hivNegativeNC15-19": 0,
#         "hivNegativeNC20-24": 0,
#         "hivNegativeNC25-29": 0,
#         "hivNegativeNC30-34": 0,
#         "hivNegativeNC35-39": 0,
#         "hivNegativeNC40-44": 0,
#         "hivNegativeNC45-49": 0,
#         "hivNegativeNC50": 0,
#         "hivPositive15-19": 0,
#         "hivPositive20-24": 0,
#         "hivPositive25-29": 0,
#         "hivPositive30-34": 0,
#         "hivPositive35-39": 0,
#         "hivPositive40-44": 0,
#         "hivPositive45-49": 0,
#         "hivPositive50": 0,
#         "hivPositiveNC15-19": 1,
#         "hivPositiveNC20-24": 1,
#         "hivPositiveNC25-29": 0,
#         "hivPositiveNC35-39": 0,
#         "hivPositiveNC40-44": 0,
#         "hivPositiveNC45-49": 0,
#         "hivPositiveNC50": 0,
#         "mc15-19": 21,
#         "mc20-24": 12,
#         "mc25-29": 0,
#         "mc30-34": 0,
#         "mc35-39": 0,
#         "mc40-44": 0,
#         "mc45-49": 0,
#         "mc50": NaN,
#         "mcMethod": 0,
#         "reason_for_referral": 0,
#         "received_on": "2025-03-28T08:35:41.849985Z",
#         "recordingMonth": "January",
#         "referralToOtherServices": 0,
#         "services_referred": 0,
#         "sgDisposable15-19": 21,
#         "sgDisposable20-24": 12,
#         "sgDisposable25-29": 0,
#         "sgDisposable30-34": 0,
#         "sgDisposable35-39": 0,
#         "sgDisposable40-44": 0,
#         "sgDisposable45-49": 0,
#         "sgDisposable50": 0,
#         "sgReusable15-19": 0,
#         "sgReusable20-24": 0,
#         "sgReusable25-29": 0,
#         "sgReusable30-34": 0,
#         "sgReusable35-39": 0,
#         "sgReusable40-44": 0,
#         "sgReusable45-49": 0,
#         "sgReusable50": 0,
#         "shangring15-19": 0,
#         "shangring20-24": 0,
#         "shangring25-29": 0,
#         "shangring30-34": 0,
#         "shangring35-39": 0,
#         "shangring40-44": 0,
#         "shangring45-49": 0,
#         "shangring50": 0,
#         "total15-19HIVTested": NaN,
#         "total15-19NCHIVTested": 1,
#         "total20-24HIVTested": NaN,
#         "total20-24NCHIVTested": 1,
#         "total25-29HIVTested": NaN,
#         "total25-29NCHIVTested": 0,
#         "total30-34HIVTested": NaN,
#         "total30-34NCHIVTested": 0,
#         "total35-39HIVTested": NaN,
#         "total35-39NCHIVTested": 0,
#         "total40-44HIVTested": NaN,
#         "total40-44NCHIVTested": 0,
#         "total45-49HIVTested": NaN,
#         "total45-49NCHIVTested": 0,
#         "total50ByMethod": NaN,
#         "total50HIVTested": NaN,
#         "total50NCHIVTested": 0,
#         "totalAES": 0,
#         "totalHIVPositive": 0,
#         "totalHIVPositiveNC": 2,
#         "totalHIVUntested": 0,
#         "totalMCs": NaN,
#         "totalReferralstoOtherServices": 0,
#         "totalShangringMCs": 0,
#         "totalSurgicalDisposableMCs": 33,
#         "totalSurgicalReusableMCs": 0,
#         "total_hiv_negative_linked_to_prep": 5,
#         "total_hiv_positive_linked_to_care": 2,
#         "total_mcs_referred_for_srh_services": 1,
#         "total_mcs_referred_for_sti_services": 1,
#         "total_mcs_referred_to_other_services": 0,
#         "total_surgicalDisposable": "OK",
#         "total_surgicalReusable": 0,
#         "totalhivNegative": 33,
#         "totalhivNegativeNC": 0,
#         "uncircumcisedClientsForHTS": 1.0,
#         "vmmc_number": 0,
#         "year": "2025",
#         "facilityType": "Outreach",
#         "matchingAES": [],
#         "otherReferrals": []
#     },
#     {
#         "AERecordingMonth": 0,
#         "AERecordingSite": 0,
#         "AERecordingYear": 0,
#         "District": "MBERENGWA",
#         "ReferrelRecordingMonth": 0,
#         "ReferrelRecordingSite": 0,
#         "ReferrelRecordingYear": 0,
#         "Site_Name": "MNENE - 101029 - MISSION HOSPITAL",
#         "TotalMCsBYMethod": 2,
#         "aeComments": 0,
#         "ae_classification": 0,
#         "ae_type_code": 0,
#         "ageGroupsChange": 0,
#         "checkMonthValidation": 0,
#         "checkYearValidation": 0,
#         "checkifFacilityHasBeenSaved": 0,
#         "circumcising_cadre": 0,
#         "client_age": 0,
#         "date_ae_identified": 0,
#         "facilityName": "Gaha Clinic",
#         "followUpTotal": NaN,
#         "formType": "submission",
#         "fu15-19": 2,
#         "fu20-24": 0,
#         "fu25-29": 0,
#         "fu30-34": 0,
#         "fu35-39": 0,
#         "fu40-44": 0,
#         "fu45-49": 0,
#         "fu50": 0,
#         "high_risk_referrals_to_care": 0,
#         "hivNegative15-19": 2,
#         "hivNegative20-24": 0,
#         "hivNegative25-29": 0,
#         "hivNegative30-34": 0,
#         "hivNegative35-39": 0,
#         "hivNegative40-44": 0,
#         "hivNegative45-49": 0,
#         "hivNegative50": 0,
#         "hivNegativeNC15-19": 0,
#         "hivNegativeNC20-24": 0,
#         "hivNegativeNC25-29": 0,
#         "hivNegativeNC30-34": 0,
#         "hivNegativeNC35-39": 0,
#         "hivNegativeNC40-44": 0,
#         "hivNegativeNC45-49": 0,
#         "hivNegativeNC50": 0,
#         "hivPositive15-19": 0,
#         "hivPositive20-24": 0,
#         "hivPositive25-29": 0,
#         "hivPositive30-34": 0,
#         "hivPositive35-39": 0,
#         "hivPositive40-44": 0,
#         "hivPositive45-49": 0,
#         "hivPositive50": 0,
#         "hivPositiveNC15-19": 0,
#         "hivPositiveNC20-24": 0,
#         "hivPositiveNC25-29": 0,
#         "hivPositiveNC35-39": 0,
#         "hivPositiveNC40-44": 0,
#         "hivPositiveNC45-49": 0,
#         "hivPositiveNC50": 0,
#         "mc15-19": 2,
#         "mc20-24": 0,
#         "mc25-29": 0,
#         "mc30-34": 0,
#         "mc35-39": 0,
#         "mc40-44": 0,
#         "mc45-49": 0,
#         "mc50": NaN,
#         "mcMethod": 0,
#         "reason_for_referral": 0,
#         "received_on": "2025-03-24T14:07:29.895824Z",
#         "recordingMonth": "March",
#         "referralToOtherServices": 0,
#         "services_referred": 0,
#         "sgDisposable15-19": 2,
#         "sgDisposable20-24": 0,
#         "sgDisposable25-29": 0,
#         "sgDisposable30-34": 0,
#         "sgDisposable35-39": 0,
#         "sgDisposable40-44": 0,
#         "sgDisposable45-49": 0,
#         "sgDisposable50": 0,
#         "sgReusable15-19": 0,
#         "sgReusable20-24": 0,
#         "sgReusable25-29": 0,
#         "sgReusable30-34": 0,
#         "sgReusable35-39": 0,
#         "sgReusable40-44": 0,
#         "sgReusable45-49": 0,
#         "sgReusable50": 0,
#         "shangring15-19": 0,
#         "shangring20-24": 0,
#         "shangring25-29": 0,
#         "shangring30-34": 0,
#         "shangring35-39": 0,
#         "shangring40-44": 0,
#         "shangring45-49": 0,
#         "shangring50": 0,
#         "total15-19HIVTested": NaN,
#         "total15-19NCHIVTested": 0,
#         "total20-24HIVTested": NaN,
#         "total20-24NCHIVTested": 0,
#         "total25-29HIVTested": NaN,
#         "total25-29NCHIVTested": 0,
#         "total30-34HIVTested": NaN,
#         "total30-34NCHIVTested": 0,
#         "total35-39HIVTested": NaN,
#         "total35-39NCHIVTested": 0,
#         "total40-44HIVTested": NaN,
#         "total40-44NCHIVTested": 0,
#         "total45-49HIVTested": NaN,
#         "total45-49NCHIVTested": 0,
#         "total50ByMethod": NaN,
#         "total50HIVTested": NaN,
#         "total50NCHIVTested": 0,
#         "totalAES": 0,
#         "totalHIVPositive": 0,
#         "totalHIVPositiveNC": 0,
#         "totalHIVUntested": 0,
#         "totalMCs": NaN,
#         "totalReferralstoOtherServices": 0,
#         "totalShangringMCs": 0,
#         "totalSurgicalDisposableMCs": 2,
#         "totalSurgicalReusableMCs": 0,
#         "total_hiv_negative_linked_to_prep": 0,
#         "total_hiv_positive_linked_to_care": 0,
#         "total_mcs_referred_for_srh_services": 0,
#         "total_mcs_referred_for_sti_services": 0,
#         "total_mcs_referred_to_other_services": 0,
#         "total_surgicalDisposable": "OK",
#         "total_surgicalReusable": 0,
#         "totalhivNegative": 2,
#         "totalhivNegativeNC": 0,
#         "uncircumcisedClientsForHTS": 0.0,
#         "vmmc_number": 0,
#         "year": "2025",
#         "facilityType": "Outreach",
#         "matchingAES": [],
#         "otherReferrals": []
#     },
#     {
#         "AERecordingMonth": 0,
#         "AERecordingSite": 0,
#         "AERecordingYear": 0,
#         "District": "MBERENGWA",
#         "ReferrelRecordingMonth": 0,
#         "ReferrelRecordingSite": 0,
#         "ReferrelRecordingYear": 0,
#         "Site_Name": "MNENE - 101029 - MISSION HOSPITAL",
#         "TotalMCsBYMethod": 14,
#         "aeComments": 0,
#         "ae_classification": 0,
#         "ae_type_code": 0,
#         "ageGroupsChange": 0,
#         "checkMonthValidation": 0,
#         "checkYearValidation": 0,
#         "checkifFacilityHasBeenSaved": 0,
#         "circumcising_cadre": 0,
#         "client_age": 0,
#         "date_ae_identified": 0,
#         "facilityName": "Gaha Clinic",
#         "followUpTotal": NaN,
#         "formType": "submission",
#         "fu15-19": 12,
#         "fu20-24": 2,
#         "fu25-29": 0,
#         "fu30-34": 0,
#         "fu35-39": 0,
#         "fu40-44": 0,
#         "fu45-49": 0,
#         "fu50": 0,
#         "high_risk_referrals_to_care": 0,
#         "hivNegative15-19": 12,
#         "hivNegative20-24": 2,
#         "hivNegative25-29": 0,
#         "hivNegative30-34": 0,
#         "hivNegative35-39": 0,
#         "hivNegative40-44": 0,
#         "hivNegative45-49": 0,
#         "hivNegative50": 0,
#         "hivNegativeNC15-19": 0,
#         "hivNegativeNC20-24": 0,
#         "hivNegativeNC25-29": 0,
#         "hivNegativeNC30-34": 0,
#         "hivNegativeNC35-39": 0,
#         "hivNegativeNC40-44": 0,
#         "hivNegativeNC45-49": 0,
#         "hivNegativeNC50": 0,
#         "hivPositive15-19": 0,
#         "hivPositive20-24": 0,
#         "hivPositive25-29": 0,
#         "hivPositive30-34": 0,
#         "hivPositive35-39": 0,
#         "hivPositive40-44": 0,
#         "hivPositive45-49": 0,
#         "hivPositive50": 0,
#         "hivPositiveNC15-19": 0,
#         "hivPositiveNC20-24": 0,
#         "hivPositiveNC25-29": 0,
#         "hivPositiveNC35-39": 0,
#         "hivPositiveNC40-44": 0,
#         "hivPositiveNC45-49": 0,
#         "hivPositiveNC50": 0,
#         "mc15-19": 12,
#         "mc20-24": 2,
#         "mc25-29": 0,
#         "mc30-34": 0,
#         "mc35-39": 0,
#         "mc40-44": 0,
#         "mc45-49": 0,
#         "mc50": NaN,
#         "mcMethod": 0,
#         "reason_for_referral": 0,
#         "received_on": "2025-03-20T10:36:00.570358Z",
#         "recordingMonth": "February",
#         "referralToOtherServices": 0,
#         "services_referred": 0,
#         "sgDisposable15-19": 12,
#         "sgDisposable20-24": 2,
#         "sgDisposable25-29": 0,
#         "sgDisposable30-34": 0,
#         "sgDisposable35-39": 0,
#         "sgDisposable40-44": 0,
#         "sgDisposable45-49": 0,
#         "sgDisposable50": 0,
#         "sgReusable15-19": 0,
#         "sgReusable20-24": 0,
#         "sgReusable25-29": 0,
#         "sgReusable30-34": 0,
#         "sgReusable35-39": 0,
#         "sgReusable40-44": 0,
#         "sgReusable45-49": 0,
#         "sgReusable50": 0,
#         "shangring15-19": 0,
#         "shangring20-24": 0,
#         "shangring25-29": 0,
#         "shangring30-34": 0,
#         "shangring35-39": 0,
#         "shangring40-44": 0,
#         "shangring45-49": 0,
#         "shangring50": 0,
#         "total15-19HIVTested": NaN,
#         "total15-19NCHIVTested": 0,
#         "total20-24HIVTested": NaN,
#         "total20-24NCHIVTested": 0,
#         "total25-29HIVTested": NaN,
#         "total25-29NCHIVTested": 0,
#         "total30-34HIVTested": NaN,
#         "total30-34NCHIVTested": 0,
#         "total35-39HIVTested": NaN,
#         "total35-39NCHIVTested": 0,
#         "total40-44HIVTested": NaN,
#         "total40-44NCHIVTested": 0,
#         "total45-49HIVTested": NaN,
#         "total45-49NCHIVTested": 0,
#         "total50ByMethod": NaN,
#         "total50HIVTested": NaN,
#         "total50NCHIVTested": 0,
#         "totalAES": 0,
#         "totalHIVPositive": 0,
#         "totalHIVPositiveNC": 0,
#         "totalHIVUntested": 0,
#         "totalMCs": NaN,
#         "totalReferralstoOtherServices": 0,
#         "totalShangringMCs": 0,
#         "totalSurgicalDisposableMCs": 14,
#         "totalSurgicalReusableMCs": 0,
#         "total_hiv_negative_linked_to_prep": 0,
#         "total_hiv_positive_linked_to_care": 0,
#         "total_mcs_referred_for_srh_services": 0,
#         "total_mcs_referred_for_sti_services": 0,
#         "total_mcs_referred_to_other_services": 0,
#         "total_surgicalDisposable": "OK",
#         "total_surgicalReusable": 0,
#         "totalhivNegative": 14,
#         "totalhivNegativeNC": 0,
#         "uncircumcisedClientsForHTS": 0.0,
#         "vmmc_number": 0,
#         "year": "2025",
#         "facilityType": "Outreach",
#         "matchingAES": [],
#         "otherReferrals": []
#     },
#     {
#         "AERecordingMonth": 0,
#         "AERecordingSite": 0,
#         "AERecordingYear": 0,
#         "District": "MBERENGWA",
#         "ReferrelRecordingMonth": 0,
#         "ReferrelRecordingSite": 0,
#         "ReferrelRecordingYear": 0,
#         "Site_Name": "MNENE - 101029 - MISSION HOSPITAL",
#         "TotalMCsBYMethod": 6,
#         "aeComments": 0,
#         "ae_classification": 0,
#         "ae_type_code": 0,
#         "ageGroupsChange": 0,
#         "checkMonthValidation": 0,
#         "checkYearValidation": 0,
#         "checkifFacilityHasBeenSaved": 0,
#         "circumcising_cadre": 0,
#         "client_age": 0,
#         "date_ae_identified": 0,
#         "facilityName": "Chiedza Clinic",
#         "followUpTotal": NaN,
#         "formType": "submission",
#         "fu15-19": 3,
#         "fu20-24": 2,
#         "fu25-29": 1,
#         "fu30-34": 0,
#         "fu35-39": 0,
#         "fu40-44": 0,
#         "fu45-49": 0,
#         "fu50": 0,
#         "high_risk_referrals_to_care": 0,
#         "hivNegative15-19": 3,
#         "hivNegative20-24": 2,
#         "hivNegative25-29": 1,
#         "hivNegative30-34": 0,
#         "hivNegative35-39": 0,
#         "hivNegative40-44": 0,
#         "hivNegative45-49": 0,
#         "hivNegative50": 0,
#         "hivNegativeNC15-19": 0,
#         "hivNegativeNC20-24": 0,
#         "hivNegativeNC25-29": 0,
#         "hivNegativeNC30-34": 0,
#         "hivNegativeNC35-39": 0,
#         "hivNegativeNC40-44": 0,
#         "hivNegativeNC45-49": 0,
#         "hivNegativeNC50": 0,
#         "hivPositive15-19": 0,
#         "hivPositive20-24": 0,
#         "hivPositive25-29": 0,
#         "hivPositive30-34": 0,
#         "hivPositive35-39": 0,
#         "hivPositive40-44": 0,
#         "hivPositive45-49": 0,
#         "hivPositive50": 0,
#         "hivPositiveNC15-19": 0,
#         "hivPositiveNC20-24": 0,
#         "hivPositiveNC25-29": 0,
#         "hivPositiveNC35-39": 0,
#         "hivPositiveNC40-44": 0,
#         "hivPositiveNC45-49": 0,
#         "hivPositiveNC50": 0,
#         "mc15-19": 3,
#         "mc20-24": 2,
#         "mc25-29": 1,
#         "mc30-34": 0,
#         "mc35-39": 0,
#         "mc40-44": 0,
#         "mc45-49": 0,
#         "mc50": NaN,
#         "mcMethod": 0,
#         "reason_for_referral": 0,
#         "received_on": "2025-03-20T07:31:04.744951Z",
#         "recordingMonth": "February",
#         "referralToOtherServices": 0,
#         "services_referred": 0,
#         "sgDisposable15-19": 3,
#         "sgDisposable20-24": 2,
#         "sgDisposable25-29": 1,
#         "sgDisposable30-34": 0,
#         "sgDisposable35-39": 0,
#         "sgDisposable40-44": 0,
#         "sgDisposable45-49": 0,
#         "sgDisposable50": 0,
#         "sgReusable15-19": 0,
#         "sgReusable20-24": 0,
#         "sgReusable25-29": 0,
#         "sgReusable30-34": 0,
#         "sgReusable35-39": 0,
#         "sgReusable40-44": 0,
#         "sgReusable45-49": 0,
#         "sgReusable50": 0,
#         "shangring15-19": 0,
#         "shangring20-24": 0,
#         "shangring25-29": 0,
#         "shangring30-34": 0,
#         "shangring35-39": 0,
#         "shangring40-44": 0,
#         "shangring45-49": 0,
#         "shangring50": 0,
#         "total15-19HIVTested": NaN,
#         "total15-19NCHIVTested": 0,
#         "total20-24HIVTested": NaN,
#         "total20-24NCHIVTested": 0,
#         "total25-29HIVTested": NaN,
#         "total25-29NCHIVTested": 0,
#         "total30-34HIVTested": NaN,
#         "total30-34NCHIVTested": 0,
#         "total35-39HIVTested": NaN,
#         "total35-39NCHIVTested": 0,
#         "total40-44HIVTested": NaN,
#         "total40-44NCHIVTested": 0,
#         "total45-49HIVTested": NaN,
#         "total45-49NCHIVTested": 0,
#         "total50ByMethod": NaN,
#         "total50HIVTested": NaN,
#         "total50NCHIVTested": 0,
#         "totalAES": 0,
#         "totalHIVPositive": 0,
#         "totalHIVPositiveNC": 0,
#         "totalHIVUntested": 0,
#         "totalMCs": NaN,
#         "totalReferralstoOtherServices": 0,
#         "totalShangringMCs": 0,
#         "totalSurgicalDisposableMCs": 6,
#         "totalSurgicalReusableMCs": 0,
#         "total_hiv_negative_linked_to_prep": 0,
#         "total_hiv_positive_linked_to_care": 0,
#         "total_mcs_referred_for_srh_services": 0,
#         "total_mcs_referred_for_sti_services": 0,
#         "total_mcs_referred_to_other_services": 0,
#         "total_surgicalDisposable": "OK",
#         "total_surgicalReusable": 0,
#         "totalhivNegative": 6,
#         "totalhivNegativeNC": 0,
#         "uncircumcisedClientsForHTS": 0.0,
#         "vmmc_number": 0,
#         "year": "2025",
#         "facilityType": "Outreach",
#         "matchingAES": [],
#         "otherReferrals": []
#     },
#     {
#         "AERecordingMonth": 0,
#         "AERecordingSite": 0,
#         "AERecordingYear": 0,
#         "District": "MBERENGWA",
#         "ReferrelRecordingMonth": 0,
#         "ReferrelRecordingSite": 0,
#         "ReferrelRecordingYear": 0,
#         "Site_Name": "MNENE - 101029 - MISSION HOSPITAL",
#         "TotalMCsBYMethod": 12,
#         "aeComments": 0,
#         "ae_classification": 0,
#         "ae_type_code": 0,
#         "ageGroupsChange": 0,
#         "checkMonthValidation": 0,
#         "checkYearValidation": 0,
#         "checkifFacilityHasBeenSaved": 0,
#         "circumcising_cadre": 0,
#         "client_age": 0,
#         "date_ae_identified": 0,
#         "facilityName": "Mnene Hospital",
#         "followUpTotal": NaN,
#         "formType": "submission",
#         "fu15-19": 5,
#         "fu20-24": 4,
#         "fu25-29": 0,
#         "fu30-34": 0,
#         "fu35-39": 0,
#         "fu40-44": 0,
#         "fu45-49": 0,
#         "fu50": 0,
#         "high_risk_referrals_to_care": 1,
#         "hivNegative15-19": 5,
#         "hivNegative20-24": 4,
#         "hivNegative25-29": 0,
#         "hivNegative30-34": 0,
#         "hivNegative35-39": 0,
#         "hivNegative40-44": 0,
#         "hivNegative45-49": 0,
#         "hivNegative50": 0,
#         "hivNegativeNC15-19": 2,
#         "hivNegativeNC20-24": 1,
#         "hivNegativeNC25-29": 0,
#         "hivNegativeNC30-34": 0,
#         "hivNegativeNC35-39": 0,
#         "hivNegativeNC40-44": 0,
#         "hivNegativeNC45-49": 0,
#         "hivNegativeNC50": 0,
#         "hivPositive15-19": 0,
#         "hivPositive20-24": 0,
#         "hivPositive25-29": 0,
#         "hivPositive30-34": 0,
#         "hivPositive35-39": 0,
#         "hivPositive40-44": 0,
#         "hivPositive45-49": 0,
#         "hivPositive50": 0,
#         "hivPositiveNC15-19": 1,
#         "hivPositiveNC20-24": 0,
#         "hivPositiveNC25-29": 0,
#         "hivPositiveNC35-39": 0,
#         "hivPositiveNC40-44": 0,
#         "hivPositiveNC45-49": 0,
#         "hivPositiveNC50": 0,
#         "mc15-19": 5,
#         "mc20-24": 4,
#         "mc25-29": 0,
#         "mc30-34": 0,
#         "mc35-39": 0,
#         "mc40-44": 0,
#         "mc45-49": 0,
#         "mc50": NaN,
#         "mcMethod": 0,
#         "reason_for_referral": 0,
#         "received_on": "2025-03-20T07:28:50.687097Z",
#         "recordingMonth": "February",
#         "referralToOtherServices": 0,
#         "services_referred": 0,
#         "sgDisposable15-19": 5,
#         "sgDisposable20-24": 4,
#         "sgDisposable25-29": 0,
#         "sgDisposable30-34": 0,
#         "sgDisposable35-39": 0,
#         "sgDisposable40-44": 0,
#         "sgDisposable45-49": 0,
#         "sgDisposable50": 0,
#         "sgReusable15-19": 0,
#         "sgReusable20-24": 0,
#         "sgReusable25-29": 0,
#         "sgReusable30-34": 0,
#         "sgReusable35-39": 0,
#         "sgReusable40-44": 0,
#         "sgReusable45-49": 0,
#         "sgReusable50": 0,
#         "shangring15-19": 0,
#         "shangring20-24": 0,
#         "shangring25-29": 0,
#         "shangring30-34": 0,
#         "shangring35-39": 0,
#         "shangring40-44": 0,
#         "shangring45-49": 0,
#         "shangring50": 0,
#         "total15-19HIVTested": NaN,
#         "total15-19NCHIVTested": 3,
#         "total20-24HIVTested": NaN,
#         "total20-24NCHIVTested": 1,
#         "total25-29HIVTested": NaN,
#         "total25-29NCHIVTested": 0,
#         "total30-34HIVTested": NaN,
#         "total30-34NCHIVTested": 0,
#         "total35-39HIVTested": NaN,
#         "total35-39NCHIVTested": 0,
#         "total40-44HIVTested": NaN,
#         "total40-44NCHIVTested": 0,
#         "total45-49HIVTested": NaN,
#         "total45-49NCHIVTested": 0,
#         "total50ByMethod": NaN,
#         "total50HIVTested": NaN,
#         "total50NCHIVTested": 0,
#         "totalAES": 0,
#         "totalHIVPositive": 0,
#         "totalHIVPositiveNC": 1,
#         "totalHIVUntested": 0,
#         "totalMCs": NaN,
#         "totalReferralstoOtherServices": 0,
#         "totalShangringMCs": 0,
#         "totalSurgicalDisposableMCs": 12,
#         "totalSurgicalReusableMCs": 0,
#         "total_hiv_negative_linked_to_prep": 6,
#         "total_hiv_positive_linked_to_care": 1,
#         "total_mcs_referred_for_srh_services": 2,
#         "total_mcs_referred_for_sti_services": 2,
#         "total_mcs_referred_to_other_services": 0,
#         "total_surgicalDisposable": "OK",
#         "total_surgicalReusable": 0,
#         "totalhivNegative": 12,
#         "totalhivNegativeNC": 3,
#         "uncircumcisedClientsForHTS": 1.0,
#         "vmmc_number": 0,
#         "year": "2025",
#         "facilityType": "Static",
#         "matchingAES": [],
#         "otherReferrals": []
#     },
#     {
#         "AERecordingMonth": 0,
#         "AERecordingSite": 0,
#         "AERecordingYear": 0,
#         "District": "MBERENGWA",
#         "ReferrelRecordingMonth": 0,
#         "ReferrelRecordingSite": 0,
#         "ReferrelRecordingYear": 0,
#         "Site_Name": "MNENE - 101029 - MISSION HOSPITAL",
#         "TotalMCsBYMethod": 18,
#         "aeComments": 0,
#         "ae_classification": 0,
#         "ae_type_code": 0,
#         "ageGroupsChange": 0,
#         "checkMonthValidation": 0,
#         "checkYearValidation": 0,
#         "checkifFacilityHasBeenSaved": 0,
#         "circumcising_cadre": 0,
#         "client_age": 0,
#         "date_ae_identified": 0,
#         "facilityName": "Sandawana Clinic",
#         "followUpTotal": NaN,
#         "formType": "submission",
#         "fu15-19": 11,
#         "fu20-24": 5,
#         "fu25-29": 2,
#         "fu30-34": 0,
#         "fu35-39": 0,
#         "fu40-44": 0,
#         "fu45-49": 0,
#         "fu50": 0,
#         "high_risk_referrals_to_care": 0,
#         "hivNegative15-19": 11,
#         "hivNegative20-24": 0,
#         "hivNegative25-29": 0,
#         "hivNegative30-34": 0,
#         "hivNegative35-39": 0,
#         "hivNegative40-44": 0,
#         "hivNegative45-49": 0,
#         "hivNegative50": 0,
#         "hivNegativeNC15-19": 0,
#         "hivNegativeNC20-24": 0,
#         "hivNegativeNC25-29": 0,
#         "hivNegativeNC30-34": 0,
#         "hivNegativeNC35-39": 0,
#         "hivNegativeNC40-44": 0,
#         "hivNegativeNC45-49": 0,
#         "hivNegativeNC50": 0,
#         "hivPositive15-19": 0,
#         "hivPositive20-24": 0,
#         "hivPositive25-29": 0,
#         "hivPositive30-34": 0,
#         "hivPositive35-39": 0,
#         "hivPositive40-44": 0,
#         "hivPositive45-49": 0,
#         "hivPositive50": 0,
#         "hivPositiveNC15-19": 0,
#         "hivPositiveNC20-24": 0,
#         "hivPositiveNC25-29": 0,
#         "hivPositiveNC35-39": 0,
#         "hivPositiveNC40-44": 0,
#         "hivPositiveNC45-49": 0,
#         "hivPositiveNC50": 0,
#         "mc15-19": 11,
#         "mc20-24": 5,
#         "mc25-29": 3,
#         "mc30-34": 0,
#         "mc35-39": 0,
#         "mc40-44": 0,
#         "mc45-49": 0,
#         "mc50": NaN,
#         "mcMethod": 0,
#         "reason_for_referral": 0,
#         "received_on": "2025-03-19T14:50:03.639660Z",
#         "recordingMonth": "February",
#         "referralToOtherServices": 0,
#         "services_referred": 0,
#         "sgDisposable15-19": 0,
#         "sgDisposable20-24": 0,
#         "sgDisposable25-29": 0,
#         "sgDisposable30-34": 0,
#         "sgDisposable35-39": 0,
#         "sgDisposable40-44": 0,
#         "sgDisposable45-49": 0,
#         "sgDisposable50": 0,
#         "sgReusable15-19": 11,
#         "sgReusable20-24": 5,
#         "sgReusable25-29": 2,
#         "sgReusable30-34": 0,
#         "sgReusable35-39": 0,
#         "sgReusable40-44": 0,
#         "sgReusable45-49": 0,
#         "sgReusable50": 0,
#         "shangring15-19": 0,
#         "shangring20-24": 0,
#         "shangring25-29": 1,
#         "shangring30-34": 0,
#         "shangring35-39": 0,
#         "shangring40-44": 0,
#         "shangring45-49": 0,
#         "shangring50": 0,
#         "total15-19HIVTested": 0.0,
#         "total15-19NCHIVTested": 0,
#         "total20-24HIVTested": 0.0,
#         "total20-24NCHIVTested": 0,
#         "total25-29HIVTested": 0.0,
#         "total25-29NCHIVTested": 0,
#         "total30-34HIVTested": NaN,
#         "total30-34NCHIVTested": 0,
#         "total35-39HIVTested": NaN,
#         "total35-39NCHIVTested": 0,
#         "total40-44HIVTested": NaN,
#         "total40-44NCHIVTested": 0,
#         "total45-49HIVTested": NaN,
#         "total45-49NCHIVTested": 0,
#         "total50ByMethod": NaN,
#         "total50HIVTested": NaN,
#         "total50NCHIVTested": 0,
#         "totalAES": 0,
#         "totalHIVPositive": 0,
#         "totalHIVPositiveNC": 0,
#         "totalHIVUntested": 18,
#         "totalMCs": NaN,
#         "totalReferralstoOtherServices": 0,
#         "totalShangringMCs": 1,
#         "totalSurgicalDisposableMCs": 0,
#         "totalSurgicalReusableMCs": 17,
#         "total_hiv_negative_linked_to_prep": 0,
#         "total_hiv_positive_linked_to_care": 0,
#         "total_mcs_referred_for_srh_services": 0,
#         "total_mcs_referred_for_sti_services": 0,
#         "total_mcs_referred_to_other_services": 0,
#         "total_surgicalDisposable": "OK",
#         "total_surgicalReusable": "OK",
#         "totalhivNegative": 0,
#         "totalhivNegativeNC": 0,
#         "uncircumcisedClientsForHTS": 0.0,
#         "vmmc_number": 0,
#         "year": "2025",
#         "facilityType": "Outreach",
#         "matchingAES": [],
#         "otherReferrals": []
#     }
# ]
